# %%
import pandas as pd
import numpy as np

# STEP 1: Load the dataset
df = pd.read_csv("2024_fb_posts_president_scored_anon.csv", low_memory=False)
print("Original shape:", df.shape)

# STEP 2: Drop malformed and 100% missing columns
columns_to_drop = [
    "Sponsor Id", "Sponsor Name", "Sponsor Category",
    "illuminating_scored_messageelection_integrity_Truth_illuminating"
]
df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# STEP 3: Convert Total Interactions to numeric (remove commas)
if "Total Interactions" in df.columns:
    df["Total Interactions"] = df["Total Interactions"].astype(str).str.replace(",", "")
    df["Total Interactions"] = pd.to_numeric(df["Total Interactions"], errors='coerce')

# STEP 4: Convert date/time columns to datetime
datetime_columns = ["Post Created"]
for col in datetime_columns:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors='coerce')

# Optional: combine date + time into full datetime
if {"Post Created Date", "Post Created Time"}.issubset(df.columns):
    df["Post Created Timestamp"] = pd.to_datetime(
        df["Post Created Date"] + " " + df["Post Created Time"],
        errors="coerce"
    )

# STEP 5: Handle 56% missing columns
for col in ["Video Share Status", "Video Length"]:
    if col in df.columns:
        df[col] = df[col].fillna("Unknown")

# STEP 6: Normalize string columns
df["Page Category"] = df["Page Category"].astype(str).str.strip().str.upper()
df["Page Admin Top Country"] = df["Page Admin Top Country"].astype(str).str.upper()

# STEP 7: Save cleaned version
df.to_csv("fb_posts_cleaned.csv", index=False)
print("Cleaned file saved as fb_posts_cleaned.csv")
# Out:
# Original shape: (19009, 56)
# C:\Users\vaibh\AppData\Local\Temp\ipykernel_23048\76874191.py:24: FutureWarning: Parsed string "2023-09-04 19:31:16 EDT" included an un-recognized timezone "EDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# Cleaned file saved as fb_posts_cleaned.csv

# %%
import csv
import math
from collections import defaultdict, Counter

def is_number(value):
    try:
        float(value)
        return True
    except:
        return False

def compute_numeric_stats(values):
    count = len(values)
    if count == 0:
        return {"count": 0, "mean": None, "min": None, "max": None, "stddev": None}
    mean = sum(values) / count
    variance = sum((x - mean) ** 2 for x in values) / count
    stddev = math.sqrt(variance)
    return {"count": count, "mean": mean, "min": min(values), "max": max(values), "stddev": stddev}

def compute_categorical_stats(values):
    counter = Counter(values)
    most_common = counter.most_common(1)[0] if counter else (None, 0)
    return {"count": len(values), "unique": len(counter), "most_common": most_common[0], "most_common_count": most_common[1]}

def aggregate_by(rows, group_keys):
    grouped = defaultdict(list)
    for row in rows:
        key = tuple(row[k] for k in group_keys)
        grouped[key].append(row)
    return grouped

def analyze(rows, group_keys=None, group_limit=3):
    columns = rows[0].keys()
    if group_keys:
        grouped = aggregate_by(rows, group_keys)
        print(f"\n=== GROUPED BY {group_keys} ===")
        for key, group in list(grouped.items())[:group_limit]:
            print(f"\nGroup {key}")
            for col in columns:
                col_values = [row[col] for row in group if row[col] not in ("", None)]
                if not col_values:
                    continue
                if all(is_number(v) for v in col_values):
                    nums = [float(v) for v in col_values]
                    stats = compute_numeric_stats(nums)
                else:
                    stats = compute_categorical_stats(col_values)
                print(f"  {col}: {stats}")
    else:
        print("\n=== OVERALL SUMMARY ===")
        for col in columns:
            col_values = [row[col] for row in rows if row[col] not in ("", None)]
            if not col_values:
                continue
            if all(is_number(v) for v in col_values):
                nums = [float(v) for v in col_values]
                stats = compute_numeric_stats(nums)
            else:
                stats = compute_categorical_stats(col_values)
            print(f"{col}: {stats}")

#Loading the data 
with open("fb_posts_cleaned.csv", newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    rows = list(reader)

#Running analysis on the data
analyze(rows)  # Overall
analyze(rows, group_keys=["Facebook_Id"])  # Grouped by Facebook id
analyze(rows, group_keys=["Facebook_Id", "post_id"])  # Grouped by Facebook id and Post id
# Out:
# === OVERALL SUMMARY ===
# Facebook_Id: {'count': 19009, 'unique': 21, 'most_common': '32fc18da91029ff09bf74fe9887eace6b5d2145809d583f696e344530508b064', 'most_common_count': 9013}
# post_id: {'count': 19009, 'unique': 19009, 'most_common': '8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138', 'most_common_count': 1}
# Page Category: {'count': 19009, 'unique': 7, 'most_common': 'PERSON', 'most_common_count': 9453}
# Page Admin Top Country: {'count': 19009, 'unique': 2, 'most_common': 'US', 'most_common_count': 16280}
# Post Created: {'count': 9378, 'unique': 8936, 'most_common': '9/22/2023 10:20', 'most_common_count': 6}
# Post Created Date: {'count': 19009, 'unique': 425, 'most_common': '10/31/2024', 'most_common_count': 103}
# Post Created Time: {'count': 19009, 'unique': 16102, 'most_common': '19:42:00', 'most_common_count': 7}
# Type: {'count': 16544, 'unique': 9, 'most_common': 'Link', 'most_common_count': 7404}
# Total Interactions: {'count': 19009, 'mean': 4190.439633857646, 'min': 0.0, 'max': 696853.0, 'stddev': 19002.580480639816}
# Likes: {'count': 19009, 'mean': 2377.6954074385817, 'min': 0.0, 'max': 351979.0, 'stddev': 11253.173660942848}
# Comments: {'count': 19009, 'mean': 901.583197432795, 'min': 0.0, 'max': 93872.0, 'stddev': 3681.88324663013}
# Shares: {'count': 19009, 'mean': 320.53895523173236, 'min': 0.0, 'max': 76150.0, 'stddev': 1722.114579655435}
# Love: {'count': 19009, 'mean': 413.87732126887266, 'min': 0.0, 'max': 244482.0, 'stddev': 3730.842312335024}
# Wow: {'count': 19009, 'mean': 5.8683255300120996, 'min': 0.0, 'max': 4345.0, 'stddev': 52.945585921667245}
# Haha: {'count': 19009, 'mean': 105.71971171550318, 'min': 0.0, 'max': 99276.0, 'stddev': 942.0094692244772}
# Sad: {'count': 19009, 'mean': 10.172181598190331, 'min': 0.0, 'max': 56111.0, 'stddev': 418.31400356540394}
# Angry: {'count': 19009, 'mean': 20.05550002630333, 'min': 0.0, 'max': 11814.0, 'stddev': 156.01598493667757}
# Care: {'count': 19009, 'mean': 34.92903361565574, 'min': 0.0, 'max': 85236.0, 'stddev': 790.0824307108217}
# Video Share Status: {'count': 19009, 'unique': 4, 'most_common': 'Unknown', 'most_common_count': 15738}
# Is Video Owner?: {'count': 16544, 'unique': 3, 'most_common': '-', 'most_common_count': 13280}
# Post Views: {'count': 16544, 'mean': 6485.058510638298, 'min': 0.0, 'max': 4276477.0, 'stddev': 90390.22650804598}
# Total Views: {'count': 16544, 'mean': 7461.847014023211, 'min': 0.0, 'max': 4462155.0, 'stddev': 95973.37816684392}
# Total Views For All Crossposts: {'count': 16544, 'mean': 3555.9379835589943, 'min': 0.0, 'max': 4499458.0, 'stddev': 88091.38586181619}
# Video Length: {'count': 19009, 'unique': 775, 'most_common': 'Unknown', 'most_common_count': 15738}
# Overperforming Score: {'count': 16544, 'mean': -2.744160420696325, 'min': -198.75, 'max': 246.78, 'stddev': 7.8082409618565265}
# advocacy_msg_type_illuminating: {'count': 19009, 'mean': 0.549266137092956, 'min': 0.0, 'max': 1.0, 'stddev': 0.49756692789607515}
# issue_msg_type_illuminating: {'count': 19009, 'mean': 0.4603082750276185, 'min': 0.0, 'max': 1.0, 'stddev': 0.49842207712812725}
# attack_msg_type_illuminating: {'count': 19009, 'mean': 0.2166868325530012, 'min': 0.0, 'max': 1.0, 'stddev': 0.4119874380987227}
# image_msg_type_illuminating: {'count': 19009, 'mean': 0.14856120784891366, 'min': 0.0, 'max': 1.0, 'stddev': 0.35565541662033706}
# cta_msg_type_illuminating: {'count': 19009, 'mean': 0.1328318165079699, 'min': 0.0, 'max': 1.0, 'stddev': 0.3393928771072883}
# engagement_cta_subtype_illuminating: {'count': 19009, 'mean': 0.0908517018254511, 'min': 0.0, 'max': 1.0, 'stddev': 0.2873981038574723}
# fundraising_cta_subtype_illuminating: {'count': 19009, 'mean': 0.01841233100110474, 'min': 0.0, 'max': 1.0, 'stddev': 0.13443703756112188}
# voting_cta_subtype_illuminating: {'count': 19009, 'mean': 0.023409963701404597, 'min': 0.0, 'max': 1.0, 'stddev': 0.15120164450462673}
# covid_topic_illuminating: {'count': 19009, 'mean': 0.05239623336314377, 'min': 0.0, 'max': 1.0, 'stddev': 0.22282474748667114}
# economy_topic_illuminating: {'count': 19009, 'mean': 0.09037824188542269, 'min': 0.0, 'max': 1.0, 'stddev': 0.2867228893533314}
# education_topic_illuminating: {'count': 19009, 'mean': 0.014992898100899574, 'min': 0.0, 'max': 1.0, 'stddev': 0.12152411739007042}
# environment_topic_illuminating: {'count': 19009, 'mean': 0.022252617181335158, 'min': 0.0, 'max': 1.0, 'stddev': 0.14750402777523094}
# foreign_policy_topic_illuminating: {'count': 19009, 'mean': 0.03687726866221264, 'min': 0.0, 'max': 1.0, 'stddev': 0.1884604354187574}
# governance_topic_illuminating: {'count': 19009, 'mean': 0.03109053606186543, 'min': 0.0, 'max': 1.0, 'stddev': 0.1735624228606275}
# health_topic_illuminating: {'count': 19009, 'mean': 0.04866116050291967, 'min': 0.0, 'max': 1.0, 'stddev': 0.21515866694471955}
# immigration_topic_illuminating: {'count': 19009, 'mean': 0.04082276816244937, 'min': 0.0, 'max': 1.0, 'stddev': 0.19787943238751288}
# lgbtq_issues_topic_illuminating: {'count': 19009, 'mean': 0.0033668262402020096, 'min': 0.0, 'max': 1.0, 'stddev': 0.05792659770149026}
# military_topic_illuminating: {'count': 19009, 'mean': 0.0055763059603345785, 'min': 0.0, 'max': 1.0, 'stddev': 0.07446617199891045}
# race_and_ethnicity_topic_illuminating: {'count': 19009, 'mean': 0.021568730601294123, 'min': 0.0, 'max': 1.0, 'stddev': 0.14527050788629783}
# safety_topic_illuminating: {'count': 19009, 'mean': 0.032195275921931714, 'min': 0.0, 'max': 1.0, 'stddev': 0.17651838468058334}
# social_and_cultural_topic_illuminating: {'count': 19009, 'mean': 0.06170761218370246, 'min': 0.0, 'max': 1.0, 'stddev': 0.2406237369468944}
# technology_and_privacy_topic_illuminating: {'count': 19009, 'mean': 0.0020516597401230995, 'min': 0.0, 'max': 1.0, 'stddev': 0.04524876166740762}
# womens_issue_topic_illuminating: {'count': 19009, 'mean': 0.0254616234415277, 'min': 0.0, 'max': 1.0, 'stddev': 0.15752247196273153}
# incivility_illuminating: {'count': 19009, 'mean': 0.1278867904676732, 'min': 0.0, 'max': 1.0, 'stddev': 0.33396370954274457}
# scam_illuminating: {'count': 18060, 'mean': 0.020210409745293468, 'min': 0.0, 'max': 1.0, 'stddev': 0.1407193983899193}
# freefair_illuminating: {'count': 19009, 'mean': 0.0028407596401704457, 'min': 0.0, 'max': 1.0, 'stddev': 0.053223018749759245}
# fraud_illuminating: {'count': 19009, 'mean': 0.00862749224051765, 'min': 0.0, 'max': 1.0, 'stddev': 0.0924827476784587}
# Post Created Timestamp: {'count': 19009, 'unique': 18088, 'most_common': '9/22/2023 10:20', 'most_common_count': 6}
#
# === GROUPED BY ['Facebook_Id'] ===
#
# Group ('a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813',)
#   Facebook_Id: {'count': 29, 'unique': 1, 'most_common': 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813', 'most_common_count': 29}
#   post_id: {'count': 29, 'unique': 29, 'most_common': '8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138', 'most_common_count': 1}
#   Page Category: {'count': 29, 'unique': 1, 'most_common': 'PERSON', 'most_common_count': 29}
#   Page Admin Top Country: {'count': 29, 'unique': 1, 'most_common': 'US', 'most_common_count': 29}
#   Post Created: {'count': 5, 'unique': 5, 'most_common': '9/4/2023 19:31', 'most_common_count': 1}
#   Post Created Date: {'count': 29, 'unique': 21, 'most_common': '1/11/2024', 'most_common_count': 3}
#   Post Created Time: {'count': 29, 'unique': 29, 'most_common': '19:31:16', 'most_common_count': 1}
#   Type: {'count': 29, 'unique': 5, 'most_common': 'Photo', 'most_common_count': 18}
#   Total Interactions: {'count': 29, 'mean': 115.51724137931035, 'min': 29.0, 'max': 454.0, 'stddev': 94.54778784029513}
#   Likes: {'count': 29, 'mean': 50.44827586206897, 'min': 12.0, 'max': 104.0, 'stddev': 23.90150219907058}
#   Comments: {'count': 29, 'mean': 46.793103448275865, 'min': 5.0, 'max': 329.0, 'stddev': 68.41726909968173}
#   Shares: {'count': 29, 'mean': 3.586206896551724, 'min': 0.0, 'max': 15.0, 'stddev': 3.337532036569065}
#   Love: {'count': 29, 'mean': 4.068965517241379, 'min': 0.0, 'max': 17.0, 'stddev': 4.322603258436451}
#   Wow: {'count': 29, 'mean': 0.2413793103448276, 'min': 0.0, 'max': 1.0, 'stddev': 0.42791978089623645}
#   Haha: {'count': 29, 'mean': 8.137931034482758, 'min': 1.0, 'max': 36.0, 'stddev': 7.1617958542053355}
#   Sad: {'count': 29, 'mean': 0.5517241379310345, 'min': 0.0, 'max': 12.0, 'stddev': 2.190673127485323}
#   Angry: {'count': 29, 'mean': 0.4827586206896552, 'min': 0.0, 'max': 2.0, 'stddev': 0.622602416733372}
#   Care: {'count': 29, 'mean': 1.206896551724138, 'min': 0.0, 'max': 12.0, 'stddev': 2.9288023955291136}
#   Video Share Status: {'count': 29, 'unique': 2, 'most_common': 'Unknown', 'most_common_count': 28}
#   Is Video Owner?: {'count': 29, 'unique': 2, 'most_common': '-', 'most_common_count': 28}
#   Post Views: {'count': 29, 'mean': 59.172413793103445, 'min': 0.0, 'max': 1716.0, 'stddev': 313.1109827439198}
#   Total Views: {'count': 29, 'mean': 59.96551724137931, 'min': 0.0, 'max': 1739.0, 'stddev': 317.30769172009127}
#   Total Views For All Crossposts: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Video Length: {'count': 29, 'unique': 2, 'most_common': 'Unknown', 'most_common_count': 28}
#   Overperforming Score: {'count': 29, 'mean': -0.6765517241379311, 'min': -3.35, 'max': 3.98, 'stddev': 1.7791479476812508}
#   advocacy_msg_type_illuminating: {'count': 29, 'mean': 0.5517241379310345, 'min': 0.0, 'max': 1.0, 'stddev': 0.4973174173053778}
#   issue_msg_type_illuminating: {'count': 29, 'mean': 0.3103448275862069, 'min': 0.0, 'max': 1.0, 'stddev': 0.46263475396547377}
#   attack_msg_type_illuminating: {'count': 29, 'mean': 0.1724137931034483, 'min': 0.0, 'max': 1.0, 'stddev': 0.37773969483114905}
#   image_msg_type_illuminating: {'count': 29, 'mean': 0.13793103448275862, 'min': 0.0, 'max': 1.0, 'stddev': 0.3448275862068965}
#   cta_msg_type_illuminating: {'count': 29, 'mean': 0.6206896551724138, 'min': 0.0, 'max': 1.0, 'stddev': 0.48521542343000995}
#   engagement_cta_subtype_illuminating: {'count': 29, 'mean': 0.41379310344827586, 'min': 0.0, 'max': 1.0, 'stddev': 0.4925123054167483}
#   fundraising_cta_subtype_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   voting_cta_subtype_illuminating: {'count': 29, 'mean': 0.10344827586206896, 'min': 0.0, 'max': 1.0, 'stddev': 0.3045434781492361}
#   covid_topic_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   economy_topic_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   education_topic_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   environment_topic_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   foreign_policy_topic_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   governance_topic_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   health_topic_illuminating: {'count': 29, 'mean': 0.06896551724137931, 'min': 0.0, 'max': 1.0, 'stddev': 0.2533954906327426}
#   immigration_topic_illuminating: {'count': 29, 'mean': 0.06896551724137931, 'min': 0.0, 'max': 1.0, 'stddev': 0.2533954906327426}
#   lgbtq_issues_topic_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   military_topic_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   safety_topic_illuminating: {'count': 29, 'mean': 0.06896551724137931, 'min': 0.0, 'max': 1.0, 'stddev': 0.2533954906327426}
#   social_and_cultural_topic_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   technology_and_privacy_topic_illuminating: {'count': 29, 'mean': 0.034482758620689655, 'min': 0.0, 'max': 1.0, 'stddev': 0.18246560765962697}
#   womens_issue_topic_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   incivility_illuminating: {'count': 29, 'mean': 0.10344827586206896, 'min': 0.0, 'max': 1.0, 'stddev': 0.3045434781492361}
#   scam_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   freefair_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fraud_illuminating: {'count': 29, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Post Created Timestamp: {'count': 29, 'unique': 29, 'most_common': '9/4/2023 19:31', 'most_common_count': 1}
#
# Group ('7ec2cb4abf8effe3d91de57944c56b938b4f33059a6e33dfe23b549cf229989a',)
#   Facebook_Id: {'count': 616, 'unique': 1, 'most_common': '7ec2cb4abf8effe3d91de57944c56b938b4f33059a6e33dfe23b549cf229989a', 'most_common_count': 616}
#   post_id: {'count': 616, 'unique': 616, 'most_common': 'b83adc0e8ac0aedd39f55b72d723729e114a83d41fd48b1b13c7ec782c9a0649', 'most_common_count': 1}
#   Page Category: {'count': 616, 'unique': 2, 'most_common': 'POLITICAL_CANDIDATE', 'most_common_count': 358}
#   Page Admin Top Country: {'count': 616, 'unique': 2, 'most_common': 'US', 'most_common_count': 358}
#   Post Created: {'count': 237, 'unique': 230, 'most_common': '10/20/2023 16:16', 'most_common_count': 2}
#   Post Created Date: {'count': 616, 'unique': 225, 'most_common': '10/31/2024', 'most_common_count': 26}
#   Post Created Time: {'count': 616, 'unique': 595, 'most_common': '14:29:37', 'most_common_count': 2}
#   Type: {'count': 358, 'unique': 7, 'most_common': 'Photo', 'most_common_count': 176}
#   Total Interactions: {'count': 616, 'mean': 67984.82142857143, 'min': 949.0, 'max': 696853.0, 'stddev': 73543.89106248709}
#   Likes: {'count': 616, 'mean': 39394.8474025974, 'min': 492.0, 'max': 351979.0, 'stddev': 43499.32649798916}
#   Comments: {'count': 616, 'mean': 13920.444805194806, 'min': 204.0, 'max': 93872.0, 'stddev': 13614.184025209819}
#   Shares: {'count': 616, 'mean': 4835.732142857143, 'min': 54.0, 'max': 69813.0, 'stddev': 6449.805703909818}
#   Love: {'count': 616, 'mean': 8089.590909090909, 'min': 0.0, 'max': 244482.0, 'stddev': 18484.539038849427}
#   Wow: {'count': 616, 'mean': 54.68181818181818, 'min': 0.0, 'max': 4345.0, 'stddev': 209.03947631113715}
#   Haha: {'count': 616, 'mean': 887.2045454545455, 'min': 0.0, 'max': 99276.0, 'stddev': 4568.149759409703}
#   Sad: {'count': 616, 'mean': 149.0827922077922, 'min': 0.0, 'max': 56111.0, 'stddev': 2278.2432600386824}
#   Angry: {'count': 616, 'mean': 144.04707792207793, 'min': 0.0, 'max': 11814.0, 'stddev': 682.1210779557113}
#   Care: {'count': 616, 'mean': 509.18993506493507, 'min': 0.0, 'max': 85236.0, 'stddev': 3581.2232530624674}
#   Video Share Status: {'count': 616, 'unique': 4, 'most_common': 'Unknown', 'most_common_count': 480}
#   Is Video Owner?: {'count': 358, 'unique': 3, 'most_common': '-', 'most_common_count': 222}
#   Post Views: {'count': 358, 'mean': 172083.19832402235, 'min': 0.0, 'max': 4276477.0, 'stddev': 542676.1606066027}
#   Total Views: {'count': 358, 'mean': 186387.5782122905, 'min': 0.0, 'max': 4462155.0, 'stddev': 567533.7714605867}
#   Total Views For All Crossposts: {'count': 358, 'mean': 163542.48603351956, 'min': 0.0, 'max': 4499458.0, 'stddev': 576538.4562463948}
#   Video Length: {'count': 616, 'unique': 127, 'most_common': 'Unknown', 'most_common_count': 480}
#   Overperforming Score: {'count': 358, 'mean': -2.311759776536313, 'min': -15.95, 'max': 8.73, 'stddev': 3.6383848215781756}
#   advocacy_msg_type_illuminating: {'count': 616, 'mean': 0.237012987012987, 'min': 0.0, 'max': 1.0, 'stddev': 0.42525031569673016}
#   issue_msg_type_illuminating: {'count': 616, 'mean': 0.11038961038961038, 'min': 0.0, 'max': 1.0, 'stddev': 0.3133747665458092}
#   attack_msg_type_illuminating: {'count': 616, 'mean': 0.06655844155844155, 'min': 0.0, 'max': 1.0, 'stddev': 0.2492557229348066}
#   image_msg_type_illuminating: {'count': 616, 'mean': 0.056818181818181816, 'min': 0.0, 'max': 1.0, 'stddev': 0.23149487258481094}
#   cta_msg_type_illuminating: {'count': 616, 'mean': 0.3344155844155844, 'min': 0.0, 'max': 1.0, 'stddev': 0.47178575785579574}
#   engagement_cta_subtype_illuminating: {'count': 616, 'mean': 0.18344155844155843, 'min': 0.0, 'max': 1.0, 'stddev': 0.3870281037316163}
#   fundraising_cta_subtype_illuminating: {'count': 616, 'mean': 0.00487012987012987, 'min': 0.0, 'max': 1.0, 'stddev': 0.06961617416360898}
#   voting_cta_subtype_illuminating: {'count': 616, 'mean': 0.12175324675324675, 'min': 0.0, 'max': 1.0, 'stddev': 0.32700060192343644}
#   covid_topic_illuminating: {'count': 616, 'mean': 0.29707792207792205, 'min': 0.0, 'max': 1.0, 'stddev': 0.45697114820498913}
#   economy_topic_illuminating: {'count': 616, 'mean': 0.016233766233766232, 'min': 0.0, 'max': 1.0, 'stddev': 0.12637337958460107}
#   education_topic_illuminating: {'count': 616, 'mean': 0.003246753246753247, 'min': 0.0, 'max': 1.0, 'stddev': 0.05688771255823127}
#   environment_topic_illuminating: {'count': 616, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   foreign_policy_topic_illuminating: {'count': 616, 'mean': 0.0016233766233766235, 'min': 0.0, 'max': 1.0, 'stddev': 0.04025843106375729}
#   governance_topic_illuminating: {'count': 616, 'mean': 0.008116883116883116, 'min': 0.0, 'max': 1.0, 'stddev': 0.08972736107425636}
#   health_topic_illuminating: {'count': 616, 'mean': 0.0016233766233766235, 'min': 0.0, 'max': 1.0, 'stddev': 0.04025843106375729}
#   immigration_topic_illuminating: {'count': 616, 'mean': 0.016233766233766232, 'min': 0.0, 'max': 1.0, 'stddev': 0.12637337958460107}
#   lgbtq_issues_topic_illuminating: {'count': 616, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   military_topic_illuminating: {'count': 616, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 616, 'mean': 0.006493506493506494, 'min': 0.0, 'max': 1.0, 'stddev': 0.0803202394600843}
#   safety_topic_illuminating: {'count': 616, 'mean': 0.006493506493506494, 'min': 0.0, 'max': 1.0, 'stddev': 0.0803202394600843}
#   social_and_cultural_topic_illuminating: {'count': 616, 'mean': 0.00487012987012987, 'min': 0.0, 'max': 1.0, 'stddev': 0.06961617416360898}
#   technology_and_privacy_topic_illuminating: {'count': 616, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   womens_issue_topic_illuminating: {'count': 616, 'mean': 0.0016233766233766235, 'min': 0.0, 'max': 1.0, 'stddev': 0.04025843106375729}
#   incivility_illuminating: {'count': 616, 'mean': 0.06168831168831169, 'min': 0.0, 'max': 1.0, 'stddev': 0.24058857805256964}
#   scam_illuminating: {'count': 616, 'mean': 0.02922077922077922, 'min': 0.0, 'max': 1.0, 'stddev': 0.16842483570575242}
#   freefair_illuminating: {'count': 616, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fraud_illuminating: {'count': 616, 'mean': 0.0016233766233766235, 'min': 0.0, 'max': 1.0, 'stddev': 0.04025843106375729}
#   Post Created Timestamp: {'count': 616, 'unique': 577, 'most_common': '10/31/2024 17:47', 'most_common_count': 4}
#
# Group ('058bd86861262fa71733f8515c34b729d9ebcad3d318e2a133a6c572dd80ba0b',)
#   Facebook_Id: {'count': 210, 'unique': 1, 'most_common': '058bd86861262fa71733f8515c34b729d9ebcad3d318e2a133a6c572dd80ba0b', 'most_common_count': 210}
#   post_id: {'count': 210, 'unique': 210, 'most_common': '1cea6a3ba6e5e032de0f6246ffcdcaa03cb620fe01787b14c00d5b67379b4142', 'most_common_count': 1}
#   Page Category: {'count': 210, 'unique': 1, 'most_common': 'POLITICIAN', 'most_common_count': 210}
#   Page Admin Top Country: {'count': 210, 'unique': 1, 'most_common': 'US', 'most_common_count': 210}
#   Post Created: {'count': 140, 'unique': 140, 'most_common': '9/30/2023 18:15', 'most_common_count': 1}
#   Post Created Date: {'count': 210, 'unique': 123, 'most_common': '9/28/2023', 'most_common_count': 5}
#   Post Created Time: {'count': 210, 'unique': 206, 'most_common': '17:00:01', 'most_common_count': 3}
#   Type: {'count': 210, 'unique': 4, 'most_common': 'Photo', 'most_common_count': 91}
#   Total Interactions: {'count': 210, 'mean': 105.73333333333333, 'min': 11.0, 'max': 920.0, 'stddev': 127.46788702344689}
#   Likes: {'count': 210, 'mean': 59.04761904761905, 'min': 5.0, 'max': 551.0, 'stddev': 78.55751680591754}
#   Comments: {'count': 210, 'mean': 26.34285714285714, 'min': 0.0, 'max': 425.0, 'stddev': 42.755189842911484}
#   Shares: {'count': 210, 'mean': 5.304761904761905, 'min': 0.0, 'max': 73.0, 'stddev': 6.909791271775229}
#   Love: {'count': 210, 'mean': 5.085714285714285, 'min': 0.0, 'max': 71.0, 'stddev': 8.843737935978886}
#   Wow: {'count': 210, 'mean': 0.21904761904761905, 'min': 0.0, 'max': 4.0, 'stddev': 0.5517237469699139}
#   Haha: {'count': 210, 'mean': 7.166666666666667, 'min': 0.0, 'max': 134.0, 'stddev': 14.537499402885246}
#   Sad: {'count': 210, 'mean': 0.6238095238095238, 'min': 0.0, 'max': 40.0, 'stddev': 3.0073568147690537}
#   Angry: {'count': 210, 'mean': 0.9238095238095239, 'min': 0.0, 'max': 14.0, 'stddev': 2.116579622185793}
#   Care: {'count': 210, 'mean': 1.019047619047619, 'min': 0.0, 'max': 71.0, 'stddev': 5.536856512982025}
#   Video Share Status: {'count': 210, 'unique': 3, 'most_common': 'Unknown', 'most_common_count': 143}
#   Is Video Owner?: {'count': 210, 'unique': 3, 'most_common': '-', 'most_common_count': 143}
#   Post Views: {'count': 210, 'mean': 251.93809523809523, 'min': 0.0, 'max': 17218.0, 'stddev': 1258.1595556988675}
#   Total Views: {'count': 210, 'mean': 279.75714285714287, 'min': 0.0, 'max': 17606.0, 'stddev': 1304.1786004887479}
#   Total Views For All Crossposts: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Video Length: {'count': 210, 'unique': 48, 'most_common': 'Unknown', 'most_common_count': 143}
#   Overperforming Score: {'count': 210, 'mean': -0.5605238095238095, 'min': -5.73, 'max': 7.36, 'stddev': 2.199753278785679}
#   advocacy_msg_type_illuminating: {'count': 210, 'mean': 0.5857142857142857, 'min': 0.0, 'max': 1.0, 'stddev': 0.4925982757019048}
#   issue_msg_type_illuminating: {'count': 210, 'mean': 0.5571428571428572, 'min': 0.0, 'max': 1.0, 'stddev': 0.49672396144896314}
#   attack_msg_type_illuminating: {'count': 210, 'mean': 0.2857142857142857, 'min': 0.0, 'max': 1.0, 'stddev': 0.4517539514526256}
#   image_msg_type_illuminating: {'count': 210, 'mean': 0.17142857142857143, 'min': 0.0, 'max': 1.0, 'stddev': 0.37688302737922624}
#   cta_msg_type_illuminating: {'count': 210, 'mean': 0.1523809523809524, 'min': 0.0, 'max': 1.0, 'stddev': 0.35938975741168017}
#   engagement_cta_subtype_illuminating: {'count': 210, 'mean': 0.11428571428571428, 'min': 0.0, 'max': 1.0, 'stddev': 0.318157963590287}
#   fundraising_cta_subtype_illuminating: {'count': 210, 'mean': 0.004761904761904762, 'min': 0.0, 'max': 1.0, 'stddev': 0.06884205854667123}
#   voting_cta_subtype_illuminating: {'count': 210, 'mean': 0.004761904761904762, 'min': 0.0, 'max': 1.0, 'stddev': 0.06884205854667123}
#   covid_topic_illuminating: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   economy_topic_illuminating: {'count': 210, 'mean': 0.21428571428571427, 'min': 0.0, 'max': 1.0, 'stddev': 0.41032590332414487}
#   education_topic_illuminating: {'count': 210, 'mean': 0.01904761904761905, 'min': 0.0, 'max': 1.0, 'stddev': 0.13669238185149832}
#   environment_topic_illuminating: {'count': 210, 'mean': 0.07142857142857142, 'min': 0.0, 'max': 1.0, 'stddev': 0.2575393768188564}
#   foreign_policy_topic_illuminating: {'count': 210, 'mean': 0.09523809523809523, 'min': 0.0, 'max': 1.0, 'stddev': 0.29354352395090366}
#   governance_topic_illuminating: {'count': 210, 'mean': 0.02857142857142857, 'min': 0.0, 'max': 1.0, 'stddev': 0.16659862556700858}
#   health_topic_illuminating: {'count': 210, 'mean': 0.02857142857142857, 'min': 0.0, 'max': 1.0, 'stddev': 0.16659862556700858}
#   immigration_topic_illuminating: {'count': 210, 'mean': 0.06190476190476191, 'min': 0.0, 'max': 1.0, 'stddev': 0.2409824938834285}
#   lgbtq_issues_topic_illuminating: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   military_topic_illuminating: {'count': 210, 'mean': 0.014285714285714285, 'min': 0.0, 'max': 1.0, 'stddev': 0.11866605518454393}
#   race_and_ethnicity_topic_illuminating: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   safety_topic_illuminating: {'count': 210, 'mean': 0.04285714285714286, 'min': 0.0, 'max': 1.0, 'stddev': 0.20253495541082608}
#   social_and_cultural_topic_illuminating: {'count': 210, 'mean': 0.004761904761904762, 'min': 0.0, 'max': 1.0, 'stddev': 0.06884205854667123}
#   technology_and_privacy_topic_illuminating: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   womens_issue_topic_illuminating: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   incivility_illuminating: {'count': 210, 'mean': 0.1761904761904762, 'min': 0.0, 'max': 1.0, 'stddev': 0.38098214169465927}
#   scam_illuminating: {'count': 210, 'mean': 0.009523809523809525, 'min': 0.0, 'max': 1.0, 'stddev': 0.09712418121129114}
#   freefair_illuminating: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fraud_illuminating: {'count': 210, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Post Created Timestamp: {'count': 210, 'unique': 210, 'most_common': '9/30/2023 18:15', 'most_common_count': 1}
#
# === GROUPED BY ['Facebook_Id', 'post_id'] ===
#
# Group ('a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813', '8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138')
#   Facebook_Id: {'count': 1, 'unique': 1, 'most_common': 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813', 'most_common_count': 1}
#   post_id: {'count': 1, 'unique': 1, 'most_common': '8570b69695e00d8f06b12398ed525497e1712b5369c6fc2138fe98f69811c138', 'most_common_count': 1}
#   Page Category: {'count': 1, 'unique': 1, 'most_common': 'PERSON', 'most_common_count': 1}
#   Page Admin Top Country: {'count': 1, 'unique': 1, 'most_common': 'US', 'most_common_count': 1}
#   Post Created: {'count': 1, 'unique': 1, 'most_common': '9/4/2023 19:31', 'most_common_count': 1}
#   Post Created Date: {'count': 1, 'unique': 1, 'most_common': '9/4/2023', 'most_common_count': 1}
#   Post Created Time: {'count': 1, 'unique': 1, 'most_common': '19:31:16', 'most_common_count': 1}
#   Type: {'count': 1, 'unique': 1, 'most_common': 'Photo', 'most_common_count': 1}
#   Total Interactions: {'count': 1, 'mean': 261.0, 'min': 261.0, 'max': 261.0, 'stddev': 0.0}
#   Likes: {'count': 1, 'mean': 104.0, 'min': 104.0, 'max': 104.0, 'stddev': 0.0}
#   Comments: {'count': 1, 'mean': 121.0, 'min': 121.0, 'max': 121.0, 'stddev': 0.0}
#   Shares: {'count': 1, 'mean': 8.0, 'min': 8.0, 'max': 8.0, 'stddev': 0.0}
#   Love: {'count': 1, 'mean': 12.0, 'min': 12.0, 'max': 12.0, 'stddev': 0.0}
#   Wow: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Haha: {'count': 1, 'mean': 14.0, 'min': 14.0, 'max': 14.0, 'stddev': 0.0}
#   Sad: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Angry: {'count': 1, 'mean': 2.0, 'min': 2.0, 'max': 2.0, 'stddev': 0.0}
#   Care: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Video Share Status: {'count': 1, 'unique': 1, 'most_common': 'Unknown', 'most_common_count': 1}
#   Is Video Owner?: {'count': 1, 'unique': 1, 'most_common': '-', 'most_common_count': 1}
#   Post Views: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Total Views: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Total Views For All Crossposts: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Video Length: {'count': 1, 'unique': 1, 'most_common': 'Unknown', 'most_common_count': 1}
#   Overperforming Score: {'count': 1, 'mean': 2.29, 'min': 2.29, 'max': 2.29, 'stddev': 0.0}
#   advocacy_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   issue_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   attack_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   image_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   cta_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   engagement_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fundraising_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   voting_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   covid_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   economy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   education_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   environment_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   foreign_policy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   governance_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   health_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   immigration_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   lgbtq_issues_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   military_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   safety_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   social_and_cultural_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   technology_and_privacy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   womens_issue_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   incivility_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   scam_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   freefair_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fraud_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Post Created Timestamp: {'count': 1, 'unique': 1, 'most_common': '9/4/2023 19:31', 'most_common_count': 1}
#
# Group ('a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813', '41ec27cecd8af40007a9faf8c3e5c9225bcff0b8d58856563bbc9d59d7dbb6e6')
#   Facebook_Id: {'count': 1, 'unique': 1, 'most_common': 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813', 'most_common_count': 1}
#   post_id: {'count': 1, 'unique': 1, 'most_common': '41ec27cecd8af40007a9faf8c3e5c9225bcff0b8d58856563bbc9d59d7dbb6e6', 'most_common_count': 1}
#   Page Category: {'count': 1, 'unique': 1, 'most_common': 'PERSON', 'most_common_count': 1}
#   Page Admin Top Country: {'count': 1, 'unique': 1, 'most_common': 'US', 'most_common_count': 1}
#   Post Created: {'count': 1, 'unique': 1, 'most_common': '9/6/2023 20:00', 'most_common_count': 1}
#   Post Created Date: {'count': 1, 'unique': 1, 'most_common': '9/6/2023', 'most_common_count': 1}
#   Post Created Time: {'count': 1, 'unique': 1, 'most_common': '20:00:56', 'most_common_count': 1}
#   Type: {'count': 1, 'unique': 1, 'most_common': 'Photo', 'most_common_count': 1}
#   Total Interactions: {'count': 1, 'mean': 135.0, 'min': 135.0, 'max': 135.0, 'stddev': 0.0}
#   Likes: {'count': 1, 'mean': 71.0, 'min': 71.0, 'max': 71.0, 'stddev': 0.0}
#   Comments: {'count': 1, 'mean': 41.0, 'min': 41.0, 'max': 41.0, 'stddev': 0.0}
#   Shares: {'count': 1, 'mean': 7.0, 'min': 7.0, 'max': 7.0, 'stddev': 0.0}
#   Love: {'count': 1, 'mean': 11.0, 'min': 11.0, 'max': 11.0, 'stddev': 0.0}
#   Wow: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   Haha: {'count': 1, 'mean': 3.0, 'min': 3.0, 'max': 3.0, 'stddev': 0.0}
#   Sad: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   Angry: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Care: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Video Share Status: {'count': 1, 'unique': 1, 'most_common': 'Unknown', 'most_common_count': 1}
#   Is Video Owner?: {'count': 1, 'unique': 1, 'most_common': '-', 'most_common_count': 1}
#   Post Views: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Total Views: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Total Views For All Crossposts: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Video Length: {'count': 1, 'unique': 1, 'most_common': 'Unknown', 'most_common_count': 1}
#   Overperforming Score: {'count': 1, 'mean': 1.18, 'min': 1.18, 'max': 1.18, 'stddev': 0.0}
#   advocacy_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   issue_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   attack_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   image_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   cta_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   engagement_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fundraising_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   voting_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   covid_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   economy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   education_topic_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   environment_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   foreign_policy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   governance_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   health_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   immigration_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   lgbtq_issues_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   military_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   safety_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   social_and_cultural_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   technology_and_privacy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   womens_issue_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   incivility_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   scam_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   freefair_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fraud_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Post Created Timestamp: {'count': 1, 'unique': 1, 'most_common': '9/6/2023 20:00', 'most_common_count': 1}
#
# Group ('a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813', '1dcb5e00cd1c8d7ee141922f50f29e59e96328231b6937870e87029c97b26377')
#   Facebook_Id: {'count': 1, 'unique': 1, 'most_common': 'a6cb7db6850459b954f7272e14d770617022639f8847cf25e6859b9453a03813', 'most_common_count': 1}
#   post_id: {'count': 1, 'unique': 1, 'most_common': '1dcb5e00cd1c8d7ee141922f50f29e59e96328231b6937870e87029c97b26377', 'most_common_count': 1}
#   Page Category: {'count': 1, 'unique': 1, 'most_common': 'PERSON', 'most_common_count': 1}
#   Page Admin Top Country: {'count': 1, 'unique': 1, 'most_common': 'US', 'most_common_count': 1}
#   Post Created: {'count': 1, 'unique': 1, 'most_common': '9/21/2023 9:48', 'most_common_count': 1}
#   Post Created Date: {'count': 1, 'unique': 1, 'most_common': '9/21/2023', 'most_common_count': 1}
#   Post Created Time: {'count': 1, 'unique': 1, 'most_common': '9:48:09', 'most_common_count': 1}
#   Type: {'count': 1, 'unique': 1, 'most_common': 'Link', 'most_common_count': 1}
#   Total Interactions: {'count': 1, 'mean': 124.0, 'min': 124.0, 'max': 124.0, 'stddev': 0.0}
#   Likes: {'count': 1, 'mean': 33.0, 'min': 33.0, 'max': 33.0, 'stddev': 0.0}
#   Comments: {'count': 1, 'mean': 74.0, 'min': 74.0, 'max': 74.0, 'stddev': 0.0}
#   Shares: {'count': 1, 'mean': 4.0, 'min': 4.0, 'max': 4.0, 'stddev': 0.0}
#   Love: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   Wow: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   Haha: {'count': 1, 'mean': 10.0, 'min': 10.0, 'max': 10.0, 'stddev': 0.0}
#   Sad: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Angry: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Care: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   Video Share Status: {'count': 1, 'unique': 1, 'most_common': 'Unknown', 'most_common_count': 1}
#   Is Video Owner?: {'count': 1, 'unique': 1, 'most_common': '-', 'most_common_count': 1}
#   Post Views: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Total Views: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Total Views For All Crossposts: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Video Length: {'count': 1, 'unique': 1, 'most_common': 'Unknown', 'most_common_count': 1}
#   Overperforming Score: {'count': 1, 'mean': 1.44, 'min': 1.44, 'max': 1.44, 'stddev': 0.0}
#   advocacy_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   issue_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   attack_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   image_msg_type_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   cta_msg_type_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   engagement_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fundraising_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   voting_cta_subtype_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   covid_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   economy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   education_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   environment_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   foreign_policy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   governance_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   health_topic_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   immigration_topic_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   lgbtq_issues_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   military_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   race_and_ethnicity_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   safety_topic_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   social_and_cultural_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   technology_and_privacy_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   womens_issue_topic_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   incivility_illuminating: {'count': 1, 'mean': 1.0, 'min': 1.0, 'max': 1.0, 'stddev': 0.0}
#   scam_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   freefair_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   fraud_illuminating: {'count': 1, 'mean': 0.0, 'min': 0.0, 'max': 0.0, 'stddev': 0.0}
#   Post Created Timestamp: {'count': 1, 'unique': 1, 'most_common': '9/21/2023 9:48', 'most_common_count': 1}
