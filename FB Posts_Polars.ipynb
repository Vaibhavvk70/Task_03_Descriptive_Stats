# %%
import polars as pl

# === STEP 1: Load the dataset using Polars ===
df = pl.read_csv("fb_posts_cleaned.csv")
print("Dataset loaded. Shape:", df.shape)

# === STEP 2: Descriptive Statistics for Numeric Columns ===
print("\n=== Overall Descriptive Statistics (numeric) ===")
print(df.describe())

# === STEP 3: Unique value counts per column ===
print("\n=== Number of Unique Values per Column ===")
for col in df.columns:
    unique_count = df[col].n_unique()
    print(f"{col}: {unique_count}")

# === STEP 4: Most Frequent Value for Each Non-Numeric Column ===
print("\n=== Most Frequent Values for Non-Numeric Columns ===")
non_numeric_cols = [col for col, dtype in df.schema.items() if dtype == pl.Utf8]
for col in non_numeric_cols:
    most_common = (
        df.select(pl.col(col).value_counts().sort(by="counts", descending=True).limit(1))
    )
    print(f"{col}:")
    print(most_common)

# === STEP 5: Grouped Stats by Facebook_Id (Only numeric columns) ===
numeric_cols = [col for col, dtype in df.schema.items() if dtype in [pl.Float64, pl.Float32, pl.Int64, pl.Int32]]
print("\n=== Grouped Stats by Facebook_Id (first 3 shown) ===")
grouped_page = (
    df.group_by("Facebook_Id")
      .agg([
          *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
          *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
          *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
          *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
          *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols]
      ])
)
print(grouped_page.head(3))

# === STEP 6: Grouped Stats by Facebook_Id and post_id (Only numeric columns) ===
print("\n=== Grouped Stats by Facebook_Id and post_id (first 3 shown) ===")
grouped_page_post = (
    df.group_by(["Facebook_Id", "post_id"])
      .agg([
          *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
          *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
          *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
          *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
          *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols]
      ])
)
print(grouped_page_post.head(3))
# Out:
# Dataset loaded. Shape: (19009, 53)
#
# === Overall Descriptive Statistics (numeric) ===
# shape: (9, 54)
# ┌────────────┬──────────────┬──────────────┬──────────────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ statistic  ┆ Facebook_Id  ┆ post_id      ┆ Page         ┆ … ┆ scam_illumin ┆ freefair_il ┆ fraud_illum ┆ Post        │
# │ ---        ┆ ---          ┆ ---          ┆ Category     ┆   ┆ ating        ┆ luminating  ┆ inating     ┆ Created     │
# │ str        ┆ str          ┆ str          ┆ ---          ┆   ┆ ---          ┆ ---         ┆ ---         ┆ Timestamp   │
# │            ┆              ┆              ┆ str          ┆   ┆ f64          ┆ f64         ┆ f64         ┆ ---         │
# │            ┆              ┆              ┆              ┆   ┆              ┆             ┆             ┆ str         │
# ╞════════════╪══════════════╪══════════════╪══════════════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ count      ┆ 19009        ┆ 19009        ┆ 19009        ┆ … ┆ 18060.0      ┆ 19009.0     ┆ 19009.0     ┆ 19009       │
# │ null_count ┆ 0            ┆ 0            ┆ 0            ┆ … ┆ 949.0        ┆ 0.0         ┆ 0.0         ┆ 0           │
# │ mean       ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.02021      ┆ 0.002841    ┆ 0.008627    ┆ null        │
# │ std        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.140723     ┆ 0.053224    ┆ 0.092485    ┆ null        │
# │ min        ┆ 058bd8686126 ┆ 0001e4a1dbad ┆ ACTOR        ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ 1/1/2024    │
# │            ┆ 2fa71733f851 ┆ f84f0f437199 ┆              ┆   ┆              ┆             ┆             ┆ 0:50        │
# │            ┆ 5c34b7…      ┆ 72b605…      ┆              ┆   ┆              ┆             ┆             ┆             │
# │ 25%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 50%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 75%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ max        ┆ fedbfaab19b5 ┆ ffff3f550f95 ┆ YOUTH_ORGANI ┆ … ┆ 1.0          ┆ 1.0         ┆ 1.0         ┆ 9/9/2023    │
# │            ┆ 112a6889b862 ┆ 017a77a35388 ┆ ZATION       ┆   ┆              ┆             ┆             ┆ 9:12        │
# │            ┆ 314ca9…      ┆ 243b4f…      ┆              ┆   ┆              ┆             ┆             ┆             │
# └────────────┴──────────────┴──────────────┴──────────────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘
#
# === Number of Unique Values per Column ===
# Facebook_Id: 21
# post_id: 19009
# Page Category: 7
# Page Admin Top Country: 2
# Post Created: 8937
# Post Created Date: 425
# Post Created Time: 16102
# Type: 10
# Total Interactions: 5312
# Likes: 4118
# Comments: 3075
# Shares: 1840
# Love: 1600
# Wow: 194
# Haha: 1154
# Sad: 239
# Angry: 423
# Care: 513
# Video Share Status: 4
# Is Video Owner?: 4
# Post Views: 2843
# Total Views: 2902
# Total Views For All Crossposts: 74
# Video Length: 775
# Overperforming Score: 2008
# advocacy_msg_type_illuminating: 2
# issue_msg_type_illuminating: 2
# attack_msg_type_illuminating: 2
# image_msg_type_illuminating: 2
# cta_msg_type_illuminating: 2
# engagement_cta_subtype_illuminating: 2
# fundraising_cta_subtype_illuminating: 2
# voting_cta_subtype_illuminating: 2
# covid_topic_illuminating: 2
# economy_topic_illuminating: 2
# education_topic_illuminating: 2
# environment_topic_illuminating: 2
# foreign_policy_topic_illuminating: 2
# governance_topic_illuminating: 2
# health_topic_illuminating: 2
# immigration_topic_illuminating: 2
# lgbtq_issues_topic_illuminating: 2
# military_topic_illuminating: 2
# race_and_ethnicity_topic_illuminating: 2
# safety_topic_illuminating: 2
# social_and_cultural_topic_illuminating: 2
# technology_and_privacy_topic_illuminating: 2
# womens_issue_topic_illuminating: 2
# incivility_illuminating: 2
# scam_illuminating: 3
# freefair_illuminating: 2
# fraud_illuminating: 2
# Post Created Timestamp: 18088
#
# === Most Frequent Values for Non-Numeric Columns ===
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      19 non_numeric_cols = [col for col, dtype in df.schema.items() if dtype == pl.Utf8]
#      20 for col in non_numeric_cols:
#      21     most_common = (
# ---> 22         df.select(pl.col(col).value_counts().sort(by="counts", descending=True).limit(1))
#      23     )
#      24     print(f"{col}:")
#      25     print(most_common)
#
# TypeError: Expr.sort() got an unexpected keyword argument 'by'

# %%
pip install polars
# Out:
# Requirement already satisfied: polars in c:\users\vaibh\anaconda3\lib\site-packages (1.31.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl

# === STEP 1: Load the dataset using Polars ===
df = pl.read_csv("fb_posts_cleaned.csv")
print("Dataset loaded. Shape:", df.shape)

# === STEP 2: Descriptive Statistics for Numeric Columns ===
print("\n=== Overall Descriptive Statistics (numeric) ===")
print(df.describe())

# === STEP 3: Unique value counts per column ===
print("\n=== Number of Unique Values per Column ===")
for col in df.columns:
    unique_count = df[col].n_unique()
    print(f"{col}: {unique_count}")

# === STEP 4: Most Frequent Value for Each Non-Numeric Column ===
print("\n=== Most Frequent Values for Non-Numeric Columns ===")
non_numeric_cols = [col for col, dtype in df.schema.items() if dtype == pl.Utf8]
for col in non_numeric_cols:
    most_common = (
        df.select(pl.col(col).value_counts().sort("counts", reverse=True).limit(1))
    )
    print(f"{col}:")
    print(most_common)

# === STEP 5: Grouped Stats by Facebook_Id (Only numeric columns) ===
numeric_cols = [col for col, dtype in df.schema.items() if dtype in [pl.Float64, pl.Float32, pl.Int64, pl.Int32]]
print("\n=== Grouped Stats by Facebook_Id (first 3 shown) ===")
grouped_page = (
    df.group_by("Facebook_Id")
      .agg([
          *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
          *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
          *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
          *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
          *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols]
      ])
)
print(grouped_page.head(3))

# === STEP 6: Grouped Stats by Facebook_Id and post_id (Only numeric columns) ===
print("\n=== Grouped Stats by Facebook_Id and post_id (first 3 shown) ===")
grouped_page_post = (
    df.group_by(["Facebook_Id", "post_id"])
      .agg([
          *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
          *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
          *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
          *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
          *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols]
      ])
)
print(grouped_page_post.head(3))
# Out:
# Dataset loaded. Shape: (19009, 53)
#
# === Overall Descriptive Statistics (numeric) ===
# shape: (9, 54)
# ┌────────────┬──────────────┬──────────────┬──────────────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ statistic  ┆ Facebook_Id  ┆ post_id      ┆ Page         ┆ … ┆ scam_illumin ┆ freefair_il ┆ fraud_illum ┆ Post        │
# │ ---        ┆ ---          ┆ ---          ┆ Category     ┆   ┆ ating        ┆ luminating  ┆ inating     ┆ Created     │
# │ str        ┆ str          ┆ str          ┆ ---          ┆   ┆ ---          ┆ ---         ┆ ---         ┆ Timestamp   │
# │            ┆              ┆              ┆ str          ┆   ┆ f64          ┆ f64         ┆ f64         ┆ ---         │
# │            ┆              ┆              ┆              ┆   ┆              ┆             ┆             ┆ str         │
# ╞════════════╪══════════════╪══════════════╪══════════════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ count      ┆ 19009        ┆ 19009        ┆ 19009        ┆ … ┆ 18060.0      ┆ 19009.0     ┆ 19009.0     ┆ 19009       │
# │ null_count ┆ 0            ┆ 0            ┆ 0            ┆ … ┆ 949.0        ┆ 0.0         ┆ 0.0         ┆ 0           │
# │ mean       ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.02021      ┆ 0.002841    ┆ 0.008627    ┆ null        │
# │ std        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.140723     ┆ 0.053224    ┆ 0.092485    ┆ null        │
# │ min        ┆ 058bd8686126 ┆ 0001e4a1dbad ┆ ACTOR        ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ 1/1/2024    │
# │            ┆ 2fa71733f851 ┆ f84f0f437199 ┆              ┆   ┆              ┆             ┆             ┆ 0:50        │
# │            ┆ 5c34b7…      ┆ 72b605…      ┆              ┆   ┆              ┆             ┆             ┆             │
# │ 25%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 50%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 75%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ max        ┆ fedbfaab19b5 ┆ ffff3f550f95 ┆ YOUTH_ORGANI ┆ … ┆ 1.0          ┆ 1.0         ┆ 1.0         ┆ 9/9/2023    │
# │            ┆ 112a6889b862 ┆ 017a77a35388 ┆ ZATION       ┆   ┆              ┆             ┆             ┆ 9:12        │
# │            ┆ 314ca9…      ┆ 243b4f…      ┆              ┆   ┆              ┆             ┆             ┆             │
# └────────────┴──────────────┴──────────────┴──────────────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘
#
# === Number of Unique Values per Column ===
# Facebook_Id: 21
# post_id: 19009
# Page Category: 7
# Page Admin Top Country: 2
# Post Created: 8937
# Post Created Date: 425
# Post Created Time: 16102
# Type: 10
# Total Interactions: 5312
# Likes: 4118
# Comments: 3075
# Shares: 1840
# Love: 1600
# Wow: 194
# Haha: 1154
# Sad: 239
# Angry: 423
# Care: 513
# Video Share Status: 4
# Is Video Owner?: 4
# Post Views: 2843
# Total Views: 2902
# Total Views For All Crossposts: 74
# Video Length: 775
# Overperforming Score: 2008
# advocacy_msg_type_illuminating: 2
# issue_msg_type_illuminating: 2
# attack_msg_type_illuminating: 2
# image_msg_type_illuminating: 2
# cta_msg_type_illuminating: 2
# engagement_cta_subtype_illuminating: 2
# fundraising_cta_subtype_illuminating: 2
# voting_cta_subtype_illuminating: 2
# covid_topic_illuminating: 2
# economy_topic_illuminating: 2
# education_topic_illuminating: 2
# environment_topic_illuminating: 2
# foreign_policy_topic_illuminating: 2
# governance_topic_illuminating: 2
# health_topic_illuminating: 2
# immigration_topic_illuminating: 2
# lgbtq_issues_topic_illuminating: 2
# military_topic_illuminating: 2
# race_and_ethnicity_topic_illuminating: 2
# safety_topic_illuminating: 2
# social_and_cultural_topic_illuminating: 2
# technology_and_privacy_topic_illuminating: 2
# womens_issue_topic_illuminating: 2
# incivility_illuminating: 2
# scam_illuminating: 3
# freefair_illuminating: 2
# fraud_illuminating: 2
# Post Created Timestamp: 18088
#
# === Most Frequent Values for Non-Numeric Columns ===
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 22
#      19 non_numeric_cols = [col for col, dtype in df.schema.items() if dtype == pl.Utf8]
#      20 for col in non_numeric_cols:
#      21     most_common = (
# ---> 22         df.select(pl.col(col).value_counts().sort("counts", reverse=True).limit(1))
#      23     )
#      24     print(f"{col}:")
#      25     print(most_common)
#
# TypeError: Expr.sort() got an unexpected keyword argument 'reverse'

# %%
import polars as pl

# === STEP 1: Load the dataset using Polars ===
df = pl.read_csv("fb_posts_cleaned.csv")
print("Dataset loaded. Shape:", df.shape)

# === STEP 2: Descriptive Statistics for Numeric Columns ===
print("\n=== Overall Descriptive Statistics (numeric) ===")
print(df.describe())

# === STEP 3: Unique value counts per column ===
print("\n=== Number of Unique Values per Column ===")
for col in df.columns:
    unique_count = df[col].n_unique()
    print(f"{col}: {unique_count}")

# === STEP 4: Most Frequent Value for Each Non-Numeric Column
print("\n=== Most Frequent Values for Non-Numeric Columns ===")
non_numeric_cols = [col for col, dtype in df.schema.items() if dtype == pl.Utf8]
for col in non_numeric_cols:
    # Get value counts
    vc = df.select(pl.col(col).value_counts())
    
    # Sort manually using safe syntax (descending=True keyword works here)
    vc_sorted = vc.sort("counts", descending=True).limit(1)
    
    print(f"{col}:")
    print(vc_sorted)

# === STEP 5: Grouped Stats by Facebook_Id (Only numeric columns) ===
numeric_cols = [col for col, dtype in df.schema.items() if dtype in [pl.Float64, pl.Float32, pl.Int64, pl.Int32]]
print("\n=== Grouped Stats by Facebook_Id (first 3 shown) ===")
grouped_page = (
    df.group_by("Facebook_Id")
      .agg([
          *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
          *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
          *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
          *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
          *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols]
      ])
)
print(grouped_page.head(3))

# === STEP 6: Grouped Stats by Facebook_Id and post_id (Only numeric columns) ===
print("\n=== Grouped Stats by Facebook_Id and post_id (first 3 shown) ===")
grouped_page_post = (
    df.group_by(["Facebook_Id", "post_id"])
      .agg([
          *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
          *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
          *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
          *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
          *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols]
      ])
)
print(grouped_page_post.head(3))
# Out:
# ✅ Dataset loaded. Shape: (19009, 53)
#
# === Overall Descriptive Statistics (numeric) ===
# shape: (9, 54)
# ┌────────────┬──────────────┬──────────────┬──────────────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ statistic  ┆ Facebook_Id  ┆ post_id      ┆ Page         ┆ … ┆ scam_illumin ┆ freefair_il ┆ fraud_illum ┆ Post        │
# │ ---        ┆ ---          ┆ ---          ┆ Category     ┆   ┆ ating        ┆ luminating  ┆ inating     ┆ Created     │
# │ str        ┆ str          ┆ str          ┆ ---          ┆   ┆ ---          ┆ ---         ┆ ---         ┆ Timestamp   │
# │            ┆              ┆              ┆ str          ┆   ┆ f64          ┆ f64         ┆ f64         ┆ ---         │
# │            ┆              ┆              ┆              ┆   ┆              ┆             ┆             ┆ str         │
# ╞════════════╪══════════════╪══════════════╪══════════════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ count      ┆ 19009        ┆ 19009        ┆ 19009        ┆ … ┆ 18060.0      ┆ 19009.0     ┆ 19009.0     ┆ 19009       │
# │ null_count ┆ 0            ┆ 0            ┆ 0            ┆ … ┆ 949.0        ┆ 0.0         ┆ 0.0         ┆ 0           │
# │ mean       ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.02021      ┆ 0.002841    ┆ 0.008627    ┆ null        │
# │ std        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.140723     ┆ 0.053224    ┆ 0.092485    ┆ null        │
# │ min        ┆ 058bd8686126 ┆ 0001e4a1dbad ┆ ACTOR        ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ 1/1/2024    │
# │            ┆ 2fa71733f851 ┆ f84f0f437199 ┆              ┆   ┆              ┆             ┆             ┆ 0:50        │
# │            ┆ 5c34b7…      ┆ 72b605…      ┆              ┆   ┆              ┆             ┆             ┆             │
# │ 25%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 50%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 75%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ max        ┆ fedbfaab19b5 ┆ ffff3f550f95 ┆ YOUTH_ORGANI ┆ … ┆ 1.0          ┆ 1.0         ┆ 1.0         ┆ 9/9/2023    │
# │            ┆ 112a6889b862 ┆ 017a77a35388 ┆ ZATION       ┆   ┆              ┆             ┆             ┆ 9:12        │
# │            ┆ 314ca9…      ┆ 243b4f…      ┆              ┆   ┆              ┆             ┆             ┆             │
# └────────────┴──────────────┴──────────────┴──────────────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘
#
# === Number of Unique Values per Column ===
# Facebook_Id: 21
# post_id: 19009
# Page Category: 7
# Page Admin Top Country: 2
# Post Created: 8937
# Post Created Date: 425
# Post Created Time: 16102
# Type: 10
# Total Interactions: 5312
# Likes: 4118
# Comments: 3075
# Shares: 1840
# Love: 1600
# Wow: 194
# Haha: 1154
# Sad: 239
# Angry: 423
# Care: 513
# Video Share Status: 4
# Is Video Owner?: 4
# Post Views: 2843
# Total Views: 2902
# Total Views For All Crossposts: 74
# Video Length: 775
# Overperforming Score: 2008
# advocacy_msg_type_illuminating: 2
# issue_msg_type_illuminating: 2
# attack_msg_type_illuminating: 2
# image_msg_type_illuminating: 2
# cta_msg_type_illuminating: 2
# engagement_cta_subtype_illuminating: 2
# fundraising_cta_subtype_illuminating: 2
# voting_cta_subtype_illuminating: 2
# covid_topic_illuminating: 2
# economy_topic_illuminating: 2
# education_topic_illuminating: 2
# environment_topic_illuminating: 2
# foreign_policy_topic_illuminating: 2
# governance_topic_illuminating: 2
# health_topic_illuminating: 2
# immigration_topic_illuminating: 2
# lgbtq_issues_topic_illuminating: 2
# military_topic_illuminating: 2
# race_and_ethnicity_topic_illuminating: 2
# safety_topic_illuminating: 2
# social_and_cultural_topic_illuminating: 2
# technology_and_privacy_topic_illuminating: 2
# womens_issue_topic_illuminating: 2
# incivility_illuminating: 2
# scam_illuminating: 3
# freefair_illuminating: 2
# fraud_illuminating: 2
# Post Created Timestamp: 18088
#
# === Most Frequent Values for Non-Numeric Columns ===
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 25
#      22 vc = df.select(pl.col(col).value_counts())
#      24 # Sort manually using safe syntax (descending=True keyword works here)
# ---> 25 vc_sorted = vc.sort("counts", descending=True).limit(1)
#      27 print(f"{col}:")
#      28 print(vc_sorted)
#
# File ~\anaconda3\Lib\site-packages\polars\dataframe\frame.py:5712, in DataFrame.sort(self, by, descending, nulls_last, multithreaded, maintain_order, *more_by)
#    5614 """
#    5615 Sort the dataframe by the given columns.
#    5616
#    (...)
#    5698 └──────┴─────┴─────┘
#    5699 """
#    5700 from polars.lazyframe import QueryOptFlags
#    5702 return (
#    5703     self.lazy()
#    5704     .sort(
#    5705         by,
#    5706         *more_by,
#    5707         descending=descending,
#    5708         nulls_last=nulls_last,
#    5709         multithreaded=multithreaded,
#    5710         maintain_order=maintain_order,
#    5711     )
# -> 5712     .collect(optimizations=QueryOptFlags._eager())
#    5713 )
#
# File ~\anaconda3\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\polars\lazyframe\opt_flags.py:330, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     329 kwargs["optimizations"] = optflags
# --> 330 return function(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\polars\lazyframe\frame.py:2332, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2330 # Only for testing purposes
#    2331 callback = _kwargs.get("post_opt_callback", callback)
# -> 2332 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: "counts" not found

# %%
pip install polars
# Out:
# Requirement already satisfied: polars in c:\users\vaibh\anaconda3\lib\site-packages (1.31.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl

# Load the cleaned dataset
df = pl.read_csv("fb_posts_cleaned.csv")
print("Dataset loaded. Shape:", df.shape)

# STEP 1: Descriptive Statistics for numeric columns
print("\n=== Descriptive Statistics (Numeric) ===")
print(df.describe())

# STEP 2: Unique value counts per column
print("\n=== Unique Value Counts per Column ===")
for col in df.columns:
    print(f"{col}: {df[col].n_unique()}")

# STEP 3: Most Frequent Non-Numeric Values
print("\n=== Most Frequent Non-Numeric Values ===")
non_numeric_cols = [col for col, dtype in df.schema.items() if dtype == pl.Utf8]
for col in non_numeric_cols:
    vc_df = df.select(pl.col(col).value_counts())
    count_col = [c for c in vc_df.columns if c != col][0]
    vc_sorted = vc_df.sort(count_col, descending=True).limit(1)
    print(f"{col}:")
    print(vc_sorted)

# STEP 4: Grouped stats by Facebook_Id
numeric_cols = [col for col, dtype in df.schema.items() if dtype in [pl.Float64, pl.Float32, pl.Int64, pl.Int32]]
grouped_page = (
    df.group_by("Facebook_Id")
    .agg([
        *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
        *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
        *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
        *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
        *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols],
    ])
)
print("\n=== Grouped Stats by Facebook_Id ===")
print(grouped_page.head(3))

# STEP 5: Grouped stats by Facebook_Id and post_id
grouped_page_post = (
    df.group_by(["Facebook_Id", "post_id"])
    .agg([
        *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
        *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
        *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
        *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
        *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols],
    ])
)
print("\n=== Grouped Stats by Facebook_Id and post_id ===")
print(grouped_page_post.head(3))
# Out:
# ✅ Dataset loaded. Shape: (19009, 53)
#
# === Descriptive Statistics (Numeric) ===
# shape: (9, 54)
# ┌────────────┬──────────────┬──────────────┬──────────────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ statistic  ┆ Facebook_Id  ┆ post_id      ┆ Page         ┆ … ┆ scam_illumin ┆ freefair_il ┆ fraud_illum ┆ Post        │
# │ ---        ┆ ---          ┆ ---          ┆ Category     ┆   ┆ ating        ┆ luminating  ┆ inating     ┆ Created     │
# │ str        ┆ str          ┆ str          ┆ ---          ┆   ┆ ---          ┆ ---         ┆ ---         ┆ Timestamp   │
# │            ┆              ┆              ┆ str          ┆   ┆ f64          ┆ f64         ┆ f64         ┆ ---         │
# │            ┆              ┆              ┆              ┆   ┆              ┆             ┆             ┆ str         │
# ╞════════════╪══════════════╪══════════════╪══════════════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ count      ┆ 19009        ┆ 19009        ┆ 19009        ┆ … ┆ 18060.0      ┆ 19009.0     ┆ 19009.0     ┆ 19009       │
# │ null_count ┆ 0            ┆ 0            ┆ 0            ┆ … ┆ 949.0        ┆ 0.0         ┆ 0.0         ┆ 0           │
# │ mean       ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.02021      ┆ 0.002841    ┆ 0.008627    ┆ null        │
# │ std        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.140723     ┆ 0.053224    ┆ 0.092485    ┆ null        │
# │ min        ┆ 058bd8686126 ┆ 0001e4a1dbad ┆ ACTOR        ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ 1/1/2024    │
# │            ┆ 2fa71733f851 ┆ f84f0f437199 ┆              ┆   ┆              ┆             ┆             ┆ 0:50        │
# │            ┆ 5c34b7…      ┆ 72b605…      ┆              ┆   ┆              ┆             ┆             ┆             │
# │ 25%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 50%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 75%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ max        ┆ fedbfaab19b5 ┆ ffff3f550f95 ┆ YOUTH_ORGANI ┆ … ┆ 1.0          ┆ 1.0         ┆ 1.0         ┆ 9/9/2023    │
# │            ┆ 112a6889b862 ┆ 017a77a35388 ┆ ZATION       ┆   ┆              ┆             ┆             ┆ 9:12        │
# │            ┆ 314ca9…      ┆ 243b4f…      ┆              ┆   ┆              ┆             ┆             ┆             │
# └────────────┴──────────────┴──────────────┴──────────────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘
#
# === Unique Value Counts per Column ===
# Facebook_Id: 21
# post_id: 19009
# Page Category: 7
# Page Admin Top Country: 2
# Post Created: 8937
# Post Created Date: 425
# Post Created Time: 16102
# Type: 10
# Total Interactions: 5312
# Likes: 4118
# Comments: 3075
# Shares: 1840
# Love: 1600
# Wow: 194
# Haha: 1154
# Sad: 239
# Angry: 423
# Care: 513
# Video Share Status: 4
# Is Video Owner?: 4
# Post Views: 2843
# Total Views: 2902
# Total Views For All Crossposts: 74
# Video Length: 775
# Overperforming Score: 2008
# advocacy_msg_type_illuminating: 2
# issue_msg_type_illuminating: 2
# attack_msg_type_illuminating: 2
# image_msg_type_illuminating: 2
# cta_msg_type_illuminating: 2
# engagement_cta_subtype_illuminating: 2
# fundraising_cta_subtype_illuminating: 2
# voting_cta_subtype_illuminating: 2
# covid_topic_illuminating: 2
# economy_topic_illuminating: 2
# education_topic_illuminating: 2
# environment_topic_illuminating: 2
# foreign_policy_topic_illuminating: 2
# governance_topic_illuminating: 2
# health_topic_illuminating: 2
# immigration_topic_illuminating: 2
# lgbtq_issues_topic_illuminating: 2
# military_topic_illuminating: 2
# race_and_ethnicity_topic_illuminating: 2
# safety_topic_illuminating: 2
# social_and_cultural_topic_illuminating: 2
# technology_and_privacy_topic_illuminating: 2
# womens_issue_topic_illuminating: 2
# incivility_illuminating: 2
# scam_illuminating: 3
# freefair_illuminating: 2
# fraud_illuminating: 2
# Post Created Timestamp: 18088
#
# === Most Frequent Non-Numeric Values ===
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 21
#      19 for col in non_numeric_cols:
#      20     vc_df = df.select(pl.col(col).value_counts())
# ---> 21     count_col = [c for c in vc_df.columns if c != col][0]
#      22     vc_sorted = vc_df.sort(count_col, descending=True).limit(1)
#      23     print(f"{col}:")
#
# IndexError: list index out of range

# %%
import polars as pl

#STEP 1: Load the cleaned dataset
df = pl.read_csv("fb_posts_cleaned.csv")
print("Dataset loaded. Shape:", df.shape)

#STEP 2: Descriptive Statistics for numeric columns
print("\n=== Descriptive Statistics (Numeric Columns) ===")
print(df.describe())

#STEP 3: Unique value counts per column
print("\n=== Unique Value Counts per Column ===")
for col in df.columns:
    print(f"{col}: {df[col].n_unique()}")

#STEP 4: Most Frequent Non-Numeric Values
print("\n=== Most Frequent Non-Numeric Values ===")
non_numeric_cols = [col for col, dtype in df.schema.items() if dtype == pl.Utf8]
for col in non_numeric_cols:
    try:
        vc_df = df.select(pl.col(col).value_counts())
        # Check if result has more than 1 column and at least 1 row
        if len(vc_df.columns) < 2 or vc_df.is_empty():
            print(f"{col}: No value counts available")
            continue
        count_col = [c for c in vc_df.columns if c != col][0]
        vc_sorted = vc_df.sort(count_col, descending=True).limit(1)
        print(f"{col}:")
        print(vc_sorted)
    except Exception as e:
        print(f"{col}: Error - {e}")

#STEP 5: Grouped stats by Facebook_Id
numeric_cols = [col for col, dtype in df.schema.items() if dtype in [pl.Float64, pl.Float32, pl.Int64, pl.Int32]]
grouped_page = (
    df.group_by("Facebook_Id")
    .agg([
        *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
        *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
        *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
        *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
        *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols],
    ])
)
print("\n=== Grouped Stats by Facebook_Id ===")
print(grouped_page.head(3))

#STEP 6: Grouped stats by Facebook_Id and post_id
grouped_page_post = (
    df.group_by(["Facebook_Id", "post_id"])
    .agg([
        *[pl.col(col).count().alias(f"{col}_count") for col in numeric_cols],
        *[pl.col(col).mean().alias(f"{col}_mean") for col in numeric_cols],
        *[pl.col(col).min().alias(f"{col}_min") for col in numeric_cols],
        *[pl.col(col).max().alias(f"{col}_max") for col in numeric_cols],
        *[pl.col(col).std().alias(f"{col}_std") for col in numeric_cols],
    ])
)
print("\n=== Grouped Stats by Facebook_Id and post_id ===")
print(grouped_page_post.head(3))
# Out:
# Dataset loaded. Shape: (19009, 53)
#
# === Descriptive Statistics (Numeric Columns) ===
# shape: (9, 54)
# ┌────────────┬──────────────┬──────────────┬──────────────┬───┬──────────────┬─────────────┬─────────────┬─────────────┐
# │ statistic  ┆ Facebook_Id  ┆ post_id      ┆ Page         ┆ … ┆ scam_illumin ┆ freefair_il ┆ fraud_illum ┆ Post        │
# │ ---        ┆ ---          ┆ ---          ┆ Category     ┆   ┆ ating        ┆ luminating  ┆ inating     ┆ Created     │
# │ str        ┆ str          ┆ str          ┆ ---          ┆   ┆ ---          ┆ ---         ┆ ---         ┆ Timestamp   │
# │            ┆              ┆              ┆ str          ┆   ┆ f64          ┆ f64         ┆ f64         ┆ ---         │
# │            ┆              ┆              ┆              ┆   ┆              ┆             ┆             ┆ str         │
# ╞════════════╪══════════════╪══════════════╪══════════════╪═══╪══════════════╪═════════════╪═════════════╪═════════════╡
# │ count      ┆ 19009        ┆ 19009        ┆ 19009        ┆ … ┆ 18060.0      ┆ 19009.0     ┆ 19009.0     ┆ 19009       │
# │ null_count ┆ 0            ┆ 0            ┆ 0            ┆ … ┆ 949.0        ┆ 0.0         ┆ 0.0         ┆ 0           │
# │ mean       ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.02021      ┆ 0.002841    ┆ 0.008627    ┆ null        │
# │ std        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.140723     ┆ 0.053224    ┆ 0.092485    ┆ null        │
# │ min        ┆ 058bd8686126 ┆ 0001e4a1dbad ┆ ACTOR        ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ 1/1/2024    │
# │            ┆ 2fa71733f851 ┆ f84f0f437199 ┆              ┆   ┆              ┆             ┆             ┆ 0:50        │
# │            ┆ 5c34b7…      ┆ 72b605…      ┆              ┆   ┆              ┆             ┆             ┆             │
# │ 25%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 50%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ 75%        ┆ null         ┆ null         ┆ null         ┆ … ┆ 0.0          ┆ 0.0         ┆ 0.0         ┆ null        │
# │ max        ┆ fedbfaab19b5 ┆ ffff3f550f95 ┆ YOUTH_ORGANI ┆ … ┆ 1.0          ┆ 1.0         ┆ 1.0         ┆ 9/9/2023    │
# │            ┆ 112a6889b862 ┆ 017a77a35388 ┆ ZATION       ┆   ┆              ┆             ┆             ┆ 9:12        │
# │            ┆ 314ca9…      ┆ 243b4f…      ┆              ┆   ┆              ┆             ┆             ┆             │
# └────────────┴──────────────┴──────────────┴──────────────┴───┴──────────────┴─────────────┴─────────────┴─────────────┘
#
# === Unique Value Counts per Column ===
# Facebook_Id: 21
# post_id: 19009
# Page Category: 7
# Page Admin Top Country: 2
# Post Created: 8937
# Post Created Date: 425
# Post Created Time: 16102
# Type: 10
# Total Interactions: 5312
# Likes: 4118
# Comments: 3075
# Shares: 1840
# Love: 1600
# Wow: 194
# Haha: 1154
# Sad: 239
# Angry: 423
# Care: 513
# Video Share Status: 4
# Is Video Owner?: 4
# Post Views: 2843
# Total Views: 2902
# Total Views For All Crossposts: 74
# Video Length: 775
# Overperforming Score: 2008
# advocacy_msg_type_illuminating: 2
# issue_msg_type_illuminating: 2
# attack_msg_type_illuminating: 2
# image_msg_type_illuminating: 2
# cta_msg_type_illuminating: 2
# engagement_cta_subtype_illuminating: 2
# fundraising_cta_subtype_illuminating: 2
# voting_cta_subtype_illuminating: 2
# covid_topic_illuminating: 2
# economy_topic_illuminating: 2
# education_topic_illuminating: 2
# environment_topic_illuminating: 2
# foreign_policy_topic_illuminating: 2
# governance_topic_illuminating: 2
# health_topic_illuminating: 2
# immigration_topic_illuminating: 2
# lgbtq_issues_topic_illuminating: 2
# military_topic_illuminating: 2
# race_and_ethnicity_topic_illuminating: 2
# safety_topic_illuminating: 2
# social_and_cultural_topic_illuminating: 2
# technology_and_privacy_topic_illuminating: 2
# womens_issue_topic_illuminating: 2
# incivility_illuminating: 2
# scam_illuminating: 3
# freefair_illuminating: 2
# fraud_illuminating: 2
# Post Created Timestamp: 18088
#
# === Most Frequent Non-Numeric Values ===
# Facebook_Id: No value counts available
# post_id: No value counts available
# Page Category: No value counts available
# Page Admin Top Country: No value counts available
# Post Created: No value counts available
# Post Created Date: No value counts available
# Post Created Time: No value counts available
# Type: No value counts available
# Video Share Status: No value counts available
# Is Video Owner?: No value counts available
# Video Length: No value counts available
# Post Created Timestamp: No value counts available
#
# === Grouped Stats by Facebook_Id ===
# shape: (3, 206)
# ┌──────────────┬──────────────┬─────────────┬──────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ Facebook_Id  ┆ Total Intera ┆ Likes_count ┆ Comments_cou ┆ … ┆ incivility_ ┆ scam_illumi ┆ freefair_il ┆ fraud_illum │
# │ ---          ┆ ctions_count ┆ ---         ┆ nt           ┆   ┆ illuminatin ┆ nating_std  ┆ luminating_ ┆ inating_std │
# │ str          ┆ ---          ┆ u32         ┆ ---          ┆   ┆ g_std       ┆ ---         ┆ std         ┆ ---         │
# │              ┆ u32          ┆             ┆ u32          ┆   ┆ ---         ┆ f64         ┆ ---         ┆ f64         │
# │              ┆              ┆             ┆              ┆   ┆ f64         ┆             ┆ f64         ┆             │
# ╞══════════════╪══════════════╪═════════════╪══════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ 32fc18da9102 ┆ 9013         ┆ 9013        ┆ 9013         ┆ … ┆ 0.332911    ┆ 0.128308    ┆ 0.064798    ┆ 0.124533    │
# │ 9ff09bf74fe9 ┆              ┆             ┆              ┆   ┆             ┆             ┆             ┆             │
# │ 887eac…      ┆              ┆             ┆              ┆   ┆             ┆             ┆             ┆             │
# │ a3fa0d15dd83 ┆ 1074         ┆ 1074        ┆ 1074         ┆ … ┆ 0.362543    ┆ 0.109403    ┆ 0.052802    ┆ 0.10516     │
# │ b910295d0b17 ┆              ┆             ┆              ┆   ┆             ┆             ┆             ┆             │
# │ f9d341…      ┆              ┆             ┆              ┆   ┆             ┆             ┆             ┆             │
# │ 834f691e4ca1 ┆ 23           ┆ 23          ┆ 23           ┆ … ┆ 0.208514    ┆ 0.208514    ┆ 0.0         ┆ 0.0         │
# │ c67a7e33db16 ┆              ┆             ┆              ┆   ┆             ┆             ┆             ┆             │
# │ 38caa5…      ┆              ┆             ┆              ┆   ┆             ┆             ┆             ┆             │
# └──────────────┴──────────────┴─────────────┴──────────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘
#
# === Grouped Stats by Facebook_Id and post_id ===
# shape: (3, 207)
# ┌──────────────┬──────────────┬──────────────┬─────────────┬───┬─────────────┬─────────────┬─────────────┬─────────────┐
# │ Facebook_Id  ┆ post_id      ┆ Total Intera ┆ Likes_count ┆ … ┆ incivility_ ┆ scam_illumi ┆ freefair_il ┆ fraud_illum │
# │ ---          ┆ ---          ┆ ctions_count ┆ ---         ┆   ┆ illuminatin ┆ nating_std  ┆ luminating_ ┆ inating_std │
# │ str          ┆ str          ┆ ---          ┆ u32         ┆   ┆ g_std       ┆ ---         ┆ std         ┆ ---         │
# │              ┆              ┆ u32          ┆             ┆   ┆ ---         ┆ f64         ┆ ---         ┆ f64         │
# │              ┆              ┆              ┆             ┆   ┆ f64         ┆             ┆ f64         ┆             │
# ╞══════════════╪══════════════╪══════════════╪═════════════╪═══╪═════════════╪═════════════╪═════════════╪═════════════╡
# │ ac24f31c4d4b ┆ b285c90acd98 ┆ 1            ┆ 1           ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ 3d5555065fa9 ┆ 303a66330082 ┆              ┆             ┆   ┆             ┆             ┆             ┆             │
# │ 558bdc…      ┆ 13dfd4…      ┆              ┆             ┆   ┆             ┆             ┆             ┆             │
# │ 32fc18da9102 ┆ 139b210efc82 ┆ 1            ┆ 1           ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ 9ff09bf74fe9 ┆ 9cd28b32cd44 ┆              ┆             ┆   ┆             ┆             ┆             ┆             │
# │ 887eac…      ┆ 1b18be…      ┆              ┆             ┆   ┆             ┆             ┆             ┆             │
# │ fc098d51a4f5 ┆ 5ae3331613e8 ┆ 1            ┆ 1           ┆ … ┆ null        ┆ null        ┆ null        ┆ null        │
# │ 7bc4bd48a4e1 ┆ 55fcf59daae7 ┆              ┆             ┆   ┆             ┆             ┆             ┆             │
# │ c0615c…      ┆ 3cc32d…      ┆              ┆             ┆   ┆             ┆             ┆             ┆             │
# └──────────────┴──────────────┴──────────────┴─────────────┴───┴─────────────┴─────────────┴─────────────┴─────────────┘
